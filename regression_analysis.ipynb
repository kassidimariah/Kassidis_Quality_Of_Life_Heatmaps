# %%
import pandas as pd
import numpy as np
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.colors as colors
import matplotlib.patches as mpatches
from pandas import cut
from matplotlib import colormaps as cmap
import folium
from shapely.ops import unary_union


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 8)
plt.style.use("ggplot")
# Out:
# C:\Users\Kassidi\AppData\Local\Temp\ipykernel_22412\392024889.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
regression_cols = [
    'Census tract 2010 ID', 
    'County Name', 
    'State/Territory',
    'Total population', 
    'Percent American Indian / Alaska Native', 
    'Percent Asian', 'Percent Black or African American alone', 
    'Percent Hispanic or Latino', 
    'Percent Native Hawaiian or Pacific',
    'Percent other races', 
    'Percent White',
    'Energy burden',
    'Energy burden (percentile)',
    'Percent pre-1960s housing (lead paint indicator)',
    'Percent pre-1960s housing (lead paint indicator) (percentile)',
    'PM2.5 in the air',
    'PM2.5 in the air (percentile)',
    'Coronary heart disease among adults aged greater than or equal to 18 years', 
    'Coronary heart disease among adults aged greater than or equal to 18 years (percentile)', 
    'Current asthma among adults aged greater than or equal to 18 years', 
    'Current asthma among adults aged greater than or equal to 18 years (percentile)',
    'Diagnosed diabetes among adults aged greater than or equal to 18 years',
    'Diagnosed diabetes among adults aged greater than or equal to 18 years (percentile)',
    'Low life expectancy (percentile)', 
    'Percent age 10 to 64', 
    'Percent age over 64', 
    'Percent age under 10'
]   

reg_stats = pd.read_csv(r"C:\\New_499_Code\\499_Cleaned_Abbreviated_CEJST_Disadvantaged_Communities_Data.csv", usecols=regression_cols)

# %%
reg_stats.head()
# Out:
#    Census tract 2010 ID     County Name State/Territory  \
# 0            1001020100  Autauga County         Alabama
# 1            1001020200  Autauga County         Alabama
# 2            1001020300  Autauga County         Alabama
# 3            1001020400  Autauga County         Alabama
# 4            1001020500  Autauga County         Alabama
#
#    Percent Black or African American alone  \
# 0                                     0.07
# 1                                     0.57
# 2                                     0.24
# 3                                     0.05
# 4                                     0.18
#
#    Percent American Indian / Alaska Native  Percent Asian  \
# 0                                      0.0           0.00
# 1                                      0.0           0.00
# 2                                      0.0           0.00
# 3                                      0.0           0.00
# 4                                      0.0           0.03
#
#    Percent Native Hawaiian or Pacific  Percent White  \
# 0                                0.00           0.83
# 1                                0.01           0.38
# 2                                0.00           0.65
# 3                                0.00           0.89
# 4                                0.00           0.70
#
#    Percent Hispanic or Latino  Percent other races  ...  PM2.5 in the air  \
# 0                        0.01                 0.00  ...              9.15
# 1                        0.01                 0.00  ...              9.18
# 2                        0.06                 0.06  ...              9.20
# 3                        0.01                 0.00  ...              9.23
# 4                        0.04                 0.00  ...              9.24
#
#    Percent pre-1960s housing (lead paint indicator) (percentile)  \
# 0                                               41.0
# 1                                               43.0
# 2                                               22.0
# 3                                               31.0
# 4                                                1.0
#
#    Percent pre-1960s housing (lead paint indicator)  \
# 0                                              17.0
# 1                                              19.0
# 2                                               5.0
# 3                                              11.0
# 4                                               0.0
#
#    Current asthma among adults aged greater than or equal to 18 years (percentile)  \
# 0                                               57.0
# 1                                               82.0
# 2                                               65.0
# 3                                               27.0
# 4                                               37.0
#
#    Current asthma among adults aged greater than or equal to 18 years  \
# 0                                              990.0
# 1                                             1100.0
# 2                                             1019.0
# 3                                              880.0
# 4                                              919.0
#
#    Diagnosed diabetes among adults aged greater than or equal to 18 years (percentile)  \
# 0                                               60.0
# 1                                               83.0
# 2                                               66.0
# 3                                               55.0
# 4                                               34.0
#
#    Diagnosed diabetes among adults aged greater than or equal to 18 years  \
# 0                                             1130.0
# 1                                             1420.0
# 2                                             1180.0
# 3                                             1080.0
# 4                                              919.0
#
#    Coronary heart disease among adults aged greater than or equal to 18 years (percentile)  \
# 0                                               59.0
# 1                                               49.0
# 2                                               60.0
# 3                                               66.0
# 4                                               31.0
#
#    Coronary heart disease among adults aged greater than or equal to 18 years  \
# 0                                              640.0
# 1                                              590.0
# 2                                              650.0
# 3                                              680.0
# 4                                              500.0
#
#    Low life expectancy (percentile)
# 0                              89.0
# 1                              65.0
# 2                               NaN
# 3                              77.0
# 4                              41.0
#
# [5 rows x 27 columns]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#conduct ols logistic regression on PM2.5 and all race variables
#regression formula
model = ols('Q("PM2.5 in the air") ~ Q("Percent American Indian / Alaska Native") + Q("Percent Asian") + Q("Percent Black or African American alone") + Q("Percent Hispanic or Latino") + Q("Percent Native Hawaiian or Pacific") + Q("Percent other races") + Q("Percent White")', data=reg_stats).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     Q("PM2.5 in the air")   R-squared:                       0.223
# Model:                               OLS   Adj. R-squared:                  0.223
# Method:                    Least Squares   F-statistic:                     2951.
# Date:                   Tue, 26 Nov 2024   Prob (F-statistic):               0.00
# Time:                           09:51:18   Log-Likelihood:            -1.3305e+05
# No. Observations:                  71903   AIC:                         2.661e+05
# Df Residuals:                      71895   BIC:                         2.662e+05
# Df Model:                              7
# Covariance Type:               nonrobust
# ================================================================================================================
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       13.7734      0.201     68.625      0.000      13.380      14.167
# Q("Percent American Indian / Alaska Native")    -9.0261      0.245    -36.803      0.000      -9.507      -8.545
# Q("Percent Asian")                              -0.8175      0.229     -3.573      0.000      -1.266      -0.369
# Q("Percent Black or African American alone")    -5.0214      0.209    -24.013      0.000      -5.431      -4.612
# Q("Percent Hispanic or Latino")                 -4.1318      0.206    -20.102      0.000      -4.535      -3.729
# Q("Percent Native Hawaiian or Pacific")          0.8858      1.160      0.764      0.445      -1.387       3.158
# Q("Percent other races")                         2.3298      0.097     24.111      0.000       2.140       2.519
# Q("Percent White")                              -6.1648      0.210    -29.356      0.000      -6.576      -5.753
# ==============================================================================
# Omnibus:                     6049.019   Durbin-Watson:                   0.146
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13827.230
# Skew:                           0.529   Prob(JB):                         0.00
# Kurtosis:                       4.870   Cond. No.                         244.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#conduct anova test on the model
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                                                      sum_sq       df  \
# Q("Percent American Indian / Alaska Native")    3210.672730      1.0
# Q("Percent Asian")                                30.262124      1.0
# Q("Percent Black or African American alone")    1366.820576      1.0
# Q("Percent Hispanic or Latino")                  957.841472      1.0
# Q("Percent Native Hawaiian or Pacific")            1.383514      1.0
# Q("Percent other races")                        1377.976919      1.0
# Q("Percent White")                              2042.820214      1.0
# Residual                                      170421.659682  71895.0
#
#                                                         F         PR(>F)
# Q("Percent American Indian / Alaska Native")  1354.471705  9.041215e-294
# Q("Percent Asian")                              12.766543   3.531051e-04
# Q("Percent Black or African American alone")   576.614296  6.482098e-127
# Q("Percent Hispanic or Latino")                404.080166   1.257830e-89
# Q("Percent Native Hawaiian or Pacific")          0.583656   4.448852e-01
# Q("Percent other races")                       581.320771  6.253697e-128
# Q("Percent White")                             861.795147  2.585764e-188
# Residual                                              NaN            NaN
